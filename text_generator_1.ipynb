# %% [markdown]
# <a href="https://colab.research.google.com/github/JaiShree-cloud/text-generator/blob/main/text_generator_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Y,L ,.;OZ!pip install transformers

# %%
from transformers import pipeline
# Out:
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work

# %%
generator = pipeline('text-generation', model='gpt2')
# Out:
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Device set to use cpu

# %%
prompt = "once upon a time, a little boy"
output = generator(prompt, max_length=50)
print(output[0]["generated_text"])
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# once upon a time, a little boy that was born and raised in the streets of New York."
#
# "We have been here as long as there have been those who have given us food and shelter and the hope and the hope of life," he wrote. "We have been here as long as there have been those who have given us education, the hope of being able to take care of our own children and our own family."
#
# He added that the city's "unbelievable power has been put to the test by the fact that the city has been built with the greatest of efforts, while every individual has been given the opportunity to make a difference."

# %%
prompt = "once upon a time there lived a ghost"
output = generator(prompt, max_length=60)
print(output[0]["generated_text"])
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=60) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# once upon a time there lived a ghostly boy who was the son of the Lord, who was the son of the Lord, and in that time came to be called 'Little Little Brother,' the son of the Lord."
#
# The Little Brother, he said, is called the "little child"—a little boy who was born in a year, in the middle of the year, and after being made into a man by the Lord for his good works, and later in his life was called "Little Prince," who was born in a year, and is now called "Little Little Brother."
#
# ...
